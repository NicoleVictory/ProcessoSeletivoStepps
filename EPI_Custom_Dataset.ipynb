# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoleVictory/ProcessoSeletivoStepps/blob/main/EPI_Custom_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.134
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 629.1/629.1 kB 10.2 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="aKK76PmLurE8e0fpqU3F")
project = rf.workspace("stepps-qev9q").project("deteccao-de-epi")
dataset = project.version(2).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Detecção-de-EPI-2 in yolov8:: 100%|██████████| 662/662 [00:00<00:00, 1408.95it/s]

# %%
import os
from ultralytics import YOLO

# Load a model

model = YOLO("yolov8n.yaml")  # build a new model from scratch
# Use the model
model.train(data=f'{dataset.location}/data.yaml', epochs=200)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Define path to video file
source = '/content/1024421504-preview.mp4'

# Run inference on the source
results= model(source, stream=True)  # generator of Results objects

# %%
output = model.predict(source='/content/1024421504-preview.mp4', conf=0.35, save=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/950) /content/1024421504-preview.mp4: 384x640 1 Colete, 10.5ms
# video 1/1 (2/950) /content/1024421504-preview.mp4: 384x640 1 Colete, 10.3ms
# video 1/1 (3/950) /content/1024421504-preview.mp4: 384x640 1 Capacete, 1 Colete, 9.0ms
# video 1/1 (4/950) /content/1024421504-preview.mp4: 384x640 1 Colete, 11.4ms
# video 1/1 (5/950) /content/1024421504-preview.mp4: 384x640 1 Capacete, 1 Colete, 9.5ms
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/Detecção-de-EPI-2/valid/labels.cache... 27 images, 0 backgrounds, 0 corrupt: 100%|██████████| 27/27 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
#                    all         27        105      0.682      0.487      0.495      0.224
#                 Botina         27         13      0.101      0.154     0.0678     0.0253
#               Capacete         27         18      0.768      0.778      0.751      0.399
#                 Colete         27         10      0.851        0.9      0.846      0.508
#             FaceShield         27          4      0.928        0.5      0.508      0.205
#                   Fone         27          9      0.742      0.323      0.363      0.222
# ...
